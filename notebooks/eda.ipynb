# %%
a=1
a
# Out:
# 1

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('../data/spotify_tracks.csv')

print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())
df.head()
# Out:
# Shape: (114000, 21)
#
# Columns:
#  ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %% [markdown]
# # Basic Info

# %%
print("=== DTYPES ===")
print(df.dtypes)

print("\n=== DESCRIBE ===")
df.describe()
# Out:
# === DTYPES ===
# Unnamed: 0            int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object
#
# === DESCRIBE ===
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# ...

# %% [markdown]
# # Missing Values

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]

print("Missing values:\n", missing)

# Visual
if len(missing) > 0:
    missing.plot(kind='bar', color='tomato', figsize=(8, 4), title='Missing Values per Column')
    plt.tight_layout()
    plt.show()
else:
    print("No missing values!")
# Out:
# Missing values:
#  artists       1
# album_name    1
# track_name    1
# dtype: int64

# %% [markdown]
# # Audio Features Distribution

# %%
audio_features = [
    'danceability', 'energy', 'valence',
    'acousticness', 'instrumentalness',
    'liveness', 'speechiness', 'loudness', 'tempo'
]

df[audio_features].hist(bins=30, figsize=(15, 10), color='steelblue', edgecolor='black')
plt.suptitle('Audio Features Distribution', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
corr = df[audio_features].corr()

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    linewidths=0.5,
    square=True
)
plt.title('Audio Features Correlation Heatmap', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 20 Genres

# %%
# Column name check kar lena — 'track_genre' ya 'genre' ho sakta hai
genre_col = 'track_genre'  # agar alag ho toh change karna

top_genres = df[genre_col].value_counts().head(20)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')
plt.title('Top 20 Genres by Track Count', fontsize=14)
plt.xlabel('Number of Tracks')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jaisi\AppData\Local\Temp\ipykernel_5088\115706897.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')

# %% [markdown]
# # Popularity Distribution

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['popularity'], bins=50, kde=True, color='mediumpurple')
plt.title('Track Popularity Distribution', fontsize=14)
plt.xlabel('Popularity Score (0-100)')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')
